# %%
python test.py \
  --nifti_path "/Users/leonardvincentramil/Desktop/Semester Project/ITKTubeTK/ITKTubeTK-MRA/Normal001-MRA.nii.gz" \
  --mask_path "/Users/leonardvincentramil/Desktop/Semester Project/ITKTubeTK/Segmentation/A2V/Normal001-MRA.nii.gz"\
  --checkpoint_path "/Users/leonardvincentramil/Downloads/model_adam_50.pth" \
  --excel_path "/Users/leonardvincentramil/Downloads/DatasetVesselV2.xlsx" \
  --selected_model "multimodal"
